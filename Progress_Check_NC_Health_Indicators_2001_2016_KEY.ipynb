# %% [markdown]
# <a href="https://colab.research.google.com/github/garrisonreid/garrisonreid.github.io/blob/master/Progress_Check_NC_Health_Indicators_2001_2016_KEY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # North Carolina Health Indicators:

# %%
### Dataset was available on the Durham Open Data/Data.gov
### https://opendurham.nc.gov/explore/dataset/county-healthy-indicators-2001-2015/export/
### Data Copied to Google Sheet: https://docs.google.com/spreadsheets/d/1Orj7sTVcSvMTiu3l06Vs28TO08TtNUrn796oTr6KVjM/edit?usp=sharing
### CSV Link: https://docs.google.com/spreadsheets/d/e/2PACX-1vRlFtQmTZKlhDlnx1KQ27-ZJJvCNG0B42BTEm4O0CVs4HHCje_rdbjo2HT2i6IQgYC3txJuxqah2QVg/pub?gid=0&single=true&output=csv

# %% [markdown]
# ###Task 0: Import necessary packages

# %%
import pandas as pd
nchealth = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRlFtQmTZKlhDlnx1KQ27-ZJJvCNG0B42BTEm4O0CVs4HHCje_rdbjo2HT2i6IQgYC3txJuxqah2QVg/pub?gid=0&single=true&output=csv')

# %%
nchealth.head()
# Out:
#            County  ...   Phys Assts per 10,000 pop: 2014
# 0  North Carolina  ...                          4.812287
# 1        Carteret  ...                          4.614275
# 2       Cleveland  ...                          2.553105
# 3         Chatham  ...                          1.018552
# 4          Bladen  ...                          1.993564
#
# [5 rows x 83 columns]

# %% [markdown]
# ### Task 1: Display the dataframe's shape

# %%
nchealth.shape
# Out:
# (101, 83)

# %% [markdown]
# ### Task 2: Display the dataframe's describe

# %%
nchealth.describe
# Out:
# <bound method NDFrame.describe of              County  ...   Phys Assts per 10,000 pop: 2014
# 0    North Carolina  ...                          4.812287
# 1          Carteret  ...                          4.614275
# 2         Cleveland  ...                          2.553105
# 3           Chatham  ...                          1.018552
# 4            Bladen  ...                          1.993564
# ..              ...  ...                               ...
# 96           Greene  ...                          1.409377
# 97             Clay  ...                          0.926441
# 98       Washington  ...                          3.943529
# 99            Vance  ...                          6.433436
# 100         Tyrrell  ...                          0.000000
#
# [101 rows x 83 columns]>

# %% [markdown]
# ### Task 3: Display the column headings for the dataframe.

# %%
nchealth.columns
# Out:
# Index(['County', '2015 NCHS Bridged Pop: total pop',
#        '2015 NCHS Bridged Pop: Percent <18',
#        '2015 NCHS Bridged Pop: Percent +65',
#        '2015 NCHS Bridged Pop: Percent White',
#        '2015 NCHS Bridged Pop: Percent African American',
#        '2015 NCHS Bridged Pop: Percent Other',
#        '2015 NCHS Bridged Pop: Percent Hispanic',
#        'Percent Low Birth Weight: 2001-2005',
#        'Percent Low Birth Weight: 2006-2010',
#        'Percent Low Birth Weight: 2011-2015',
#        'Percent Very Low Birth Weight: 2001-2005',
#        'Percent Very Low Birth Weight: 2006-2010',
#        'Percent Very Low Birth Weight: 2011-2015',
#        'Preterm Births : 2001-2005', 'Preterm Births : 2006-2010',
#        'Preterm Births : 2011-2015', 'C-Section Deliveries : 2001-2005',
#        'C-Section Deliveries : 2006-2010', 'C-Section Deliveries : 2011-2015',
#        'Teen Birth Rate: 2001-2005', 'Teen Birth Rate: 2006-2010',
# ...

# %% [markdown]
# ### Task 4: Create a dataframe instance byCounty where index is set to county.
# ### Print the head() of byCounty sorted by its new index

# %%
by_county = nchealth.set_index('County')
by_county.sort_index().head()
# Out:
#            2015 NCHS Bridged Pop: total pop  ...   Phys Assts per 10,000 pop: 2014
# County                                       ...
# Alamance                             158276  ...                          2.567575
# Alexander                             37325  ...                          1.057306
# Alleghany                             10837  ...                          1.801964
# Anson                                 25759  ...                          1.133444
# Ashe                                  27020  ...                          1.457301
#
# [5 rows x 82 columns]

# %% [markdown]
# ### Task 5: Display the nchealth dataframe's mean for series Percent Very Low Birth Weight: 2011-2015

# %%
nchealth['Percent Very Low Birth Weight: 2011-2015'].mean()
# Out:
# 1.7762376237623765

# %% [markdown]
# ### Task 6: Display the nchealth dataframe's median for series Age-adjusted Homicide Dth Rts: 2011-2015

# %%
nchealth['Age-adjusted Homicide Dth Rts: 2011-2015'].median()
# Out:
# 5.05

# %% [markdown]
# ### Task 7: Display county and max value of Age-adjusted Homicide Dth Rts: 2011-2015

# %%
nchealth[['County', 'Age-adjusted Homicide Dth Rts: 2011-2015']].sort_values(by="Age-adjusted Homicide Dth Rts: 2011-2015", ascending=False).head(1)
# Out:
#      County  Age-adjusted Homicide Dth Rts: 2011-2015
# 82  Robeson                                      21.3

# %% [markdown]
# ### Task 8: Display county and min value of Age-adjusted Diabetes Dth Rates: 2006-2010

# %%
nchealth[['County', 'Age-adjusted Diabetes Dth Rates: 2006-2010']].sort_values(by="Age-adjusted Diabetes Dth Rates: 2006-2010", ascending=True).head(1)
# Out:
#    County  Age-adjusted Diabetes Dth Rates: 2006-2010
# 77  Avery                                         7.1

# %% [markdown]
# ### Task 9: Display a dataframe of the Youth death rates: 2001-2005, 2006-2010, 2011-2015 for the coastal counties of Beaufort, Bertie, Brunswick, Camden, Carteret, Chowan, Craven, Currituck, Dare, Gates, Hertford, Hyde, New Hanover, Onslow, Pamlico, Pasquotank, Pender, Perquimans, Tyrrell, Washington

# %%
by_county[['Youth death rates: 2001-2005', 'Youth death rates: 2006-2010', 'Youth death rates: 2011-2015']].reindex(['Beaufort', 'Bertie' , 'Brunswick' , 'Camden','Carteret' , 'Chowan' , 'Craven' , 'Currituck' , 'Dare' , 'Gates' , 'Hertfort' , 'Hyde' , 'New Hanover' , 'Onslow' , 'Pamlico' , 'Pasquotank' , 'Pender' , 'Perquimans' , 'Tyrell' , 'Washington'])
# Out:
#              Youth death rates: 2001-2005  ...  Youth death rates: 2011-2015
# County                                     ...
# Beaufort                             92.7  ...                          77.0
# Bertie                              109.9  ...                          71.6
# Brunswick                            65.3  ...                          57.9
# Camden                               29.4  ...                          73.6
# Carteret                             68.2  ...                          47.4
# Chowan                               64.0  ...                          64.3
# Craven                               73.9  ...                          62.2
# Currituck                            73.2  ...                          43.5
# Dare                                 93.1  ...                          29.0
# Gates                                70.6  ...                          31.3
# Hertfort                              NaN  ...                           NaN
# ...

# %% [markdown]
# ### Task 10: Use the loc() method to isolate Person county and its 'Age-adjusted Cancer Dth Rates: 2001-2005' 'Age-adjusted Cancer Dth Rates: 2006-2010' 'Age-adjusted Cancer Dth Rates: 2011-2015' columns

# %%
by_county[['Age-adjusted Cancer Dth Rates: 2001-2005','Age-adjusted Cancer Dth Rates: 2006-2010','Age-adjusted Cancer Dth Rates: 2011-2015']].reindex(['Person'])
# Out:
#         Age-adjusted Cancer Dth Rates: 2001-2005  ...  Age-adjusted Cancer Dth Rates: 2011-2015
# County                                            ...
# Person                                     212.6  ...                                     190.3
#
# [1 rows x 3 columns]

# %% [markdown]
# ### Task 11: Use the iLoc() method to select the results of the 5th-10th counties with the highest values in column Age-adjusted CVD Dth Rates: 2006-2010

# %%
nchealth[['County','Age-adjusted CVD Dth Rates: 2006-2010']].sort_values(by='Age-adjusted CVD Dth Rates: 2006-2010', ascending = False).iloc[5:11]
# Out:
#      County  Age-adjusted CVD Dth Rates: 2006-2010
# 67    Jones                                  352.2
# 28    Swain                                  352.1
# 16    Anson                                  342.4
# 4    Bladen                                  341.1
# 13     Hyde                                  333.0
# 20  Lincoln                                  329.7

# %% [markdown]
# ### Task 12: Use the describe() method on a dataframe of columns of County, Age-adjusted Stroke Dth Rts: 2001-2005,	Age-adjusted Stroke Dth Rts: 2006-2010, and	Age-adjusted Stroke Dth Rts: 2011-2015 (columns related to stroke deaths).

# %%
nchealth[['County','Age-adjusted Stroke Dth Rts: 2001-2005','Age-adjusted Stroke Dth Rts: 2006-2010','Age-adjusted Stroke Dth Rts: 2011-2015']].describe()
# Out:
#        Age-adjusted Stroke Dth Rts: 2001-2005  ...  Age-adjusted Stroke Dth Rts: 2011-2015
# count                              101.000000  ...                              101.000000
# mean                                67.473267  ...                               43.670297
# std                                 13.670895  ...                               10.015623
# min                                 43.700000  ...                               26.600000
# 25%                                 59.500000  ...                               37.000000
# 50%                                 65.300000  ...                               42.300000
# 75%                                 74.100000  ...                               48.900000
# max                                116.000000  ...                               95.300000
#
# [8 rows x 3 columns]

# %% [markdown]
# ### Task 13: Create a scatter graph showing some data from the data frame. Add x and y axis labels and a title.

# %%
import matplotlib.pyplot as plt
plt.scatter(nchealth['Percent Very Low Birth Weight: 2006-2010'], nchealth['Percent Low Birth Weight: 2006-2010'])
plt.xlabel("Percent of Very Low Birth")
plt.ylabel("Percent of Low Birth")
plt.title('Comparing birth weights')
# Out:
# Text(0.5, 1.0, 'Comparing birth weights')

# %% [markdown]
# ### Task 14: Create a histogram graph showing some data from the data frame. Add x and y axis labels and a title.

# %%
plt.hist(nchealth['Youth death rates: 2011-2015'])
# Out:
# (array([ 5.,  4., 13., 20., 31., 10.,  8.,  6.,  3.,  1.]),
#  array([ 14.  ,  24.45,  34.9 ,  45.35,  55.8 ,  66.25,  76.7 ,  87.15,
#          97.6 , 108.05, 118.5 ]),
#  <a list of 10 Patch objects>)
